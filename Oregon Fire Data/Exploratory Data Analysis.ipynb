# %%
#importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import urllib.request
import time
import datetime
import pickle
from datetime import datetime, timedelta

# %%
#loading dataframe
pickle_in=open('fireCleaned.pickle','rb')
df = pickle.load(pickle_in)

# %%
#loading original data
#reading xlsx
xls = pd.ExcelFile('20050101--20171231_ODF_Fire_Point_Data.xlsx')
oregon = pd.read_excel(xls, '20050101--20171231_ODF_FireData')

# %%
dfcleaned = df.drop(['API_End','API_Start','API_Time','LandmarkLocation'],axis=1)

# %%
dfcleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12874 entries, 0 to 13451
# Data columns (total 34 columns):
# ID                   12874 non-null int64
# CreationDate         12872 non-null datetime64[ns]
# ModifiedDate         12874 non-null datetime64[ns]
# FireYear             12874 non-null int64
# Area                 12874 non-null object
# District             12874 non-null int64
# Unit                 12874 non-null int64
# FireNumber           12874 non-null int64
# FiscalYear           12874 non-null int64
# FireName             12874 non-null object
# Twn                  12872 non-null object
# Rng                  12871 non-null object
# Sec                  12872 non-null float64
# Subdiv               12858 non-null object
# Long_DD              12871 non-null float64
# Lat_DD               12871 non-null float64
# LO_Name              12866 non-null object
# HumanOrLightning     12874 non-null object
# CauseByDesc          12810 non-null object
# GeneralDesc          12873 non-null object
# SpecificDesc         12761 non-null object
# Cause_Comments       5934 non-null object
# Ign_DateTime         12874 non-null datetime64[ns]
# ReportDateAndTime    12874 non-null datetime64[ns]
# Control_DateTime     12822 non-null datetime64[ns]
# FireTotalAcres       12825 non-null float64
# ODFProtectedAcres    12874 non-null float64
# Temp                 12870 non-null float64
# DewPoint             12870 non-null float64
# Humidity             12870 non-null float64
# Weather              12870 non-null object
# PrecipProb           12865 non-null float64
# PrecipInten          12865 non-null float64
# Wind                 12870 non-null float64
# dtypes: datetime64[ns](5), float64(11), int64(6), object(12)
# memory usage: 3.4+ MB

# %%
#dropping all columns that are not relevant
dfcleaned.drop(['ID','FireName','Rng','SpecificDesc','Cause_Comments','CreationDate','ModifiedDate','LO_Name'],axis=1,inplace=True)

# %%
dfcleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12874 entries, 0 to 13451
# Data columns (total 26 columns):
# FireYear             12874 non-null int64
# Area                 12874 non-null object
# District             12874 non-null int64
# Unit                 12874 non-null int64
# FireNumber           12874 non-null int64
# FiscalYear           12874 non-null int64
# Twn                  12872 non-null object
# Sec                  12872 non-null float64
# Subdiv               12858 non-null object
# Long_DD              12871 non-null float64
# Lat_DD               12871 non-null float64
# HumanOrLightning     12874 non-null object
# CauseByDesc          12810 non-null object
# GeneralDesc          12873 non-null object
# Ign_DateTime         12874 non-null datetime64[ns]
# ReportDateAndTime    12874 non-null datetime64[ns]
# Control_DateTime     12822 non-null datetime64[ns]
# FireTotalAcres       12825 non-null float64
# ODFProtectedAcres    12874 non-null float64
# Temp                 12870 non-null float64
# DewPoint             12870 non-null float64
# Humidity             12870 non-null float64
# Weather              12870 non-null object
# PrecipProb           12865 non-null float64
# PrecipInten          12865 non-null float64
# Wind                 12870 non-null float64
# dtypes: datetime64[ns](3), float64(11), int64(5), object(7)
# memory usage: 2.7+ MB

# %%
#dropping blank values
dfcleaned.dropna(subset=['CauseByDesc','Control_DateTime','PrecipProb','PrecipInten'],inplace=True)

# %%
#adding a column for duration of fire
dfcleaned['FireDuration']= dfcleaned['Control_DateTime'] - dfcleaned['Ign_DateTime']

# %%
dfcleaned['Days']=[x.days for x in dfcleaned['FireDuration']]

# %%
dfcleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12804 entries, 0 to 13440
# Data columns (total 28 columns):
# FireYear             12804 non-null int64
# Area                 12804 non-null object
# District             12804 non-null int64
# Unit                 12804 non-null int64
# FireNumber           12804 non-null int64
# FiscalYear           12804 non-null int64
# Twn                  12804 non-null object
# Sec                  12804 non-null float64
# Subdiv               12802 non-null object
# Long_DD              12804 non-null float64
# Lat_DD               12804 non-null float64
# HumanOrLightning     12804 non-null object
# CauseByDesc          12804 non-null object
# GeneralDesc          12803 non-null object
# Ign_DateTime         12804 non-null datetime64[ns]
# ReportDateAndTime    12804 non-null datetime64[ns]
# Control_DateTime     12804 non-null datetime64[ns]
# FireTotalAcres       12804 non-null float64
# ODFProtectedAcres    12804 non-null float64
# Temp                 12804 non-null float64
# DewPoint             12804 non-null float64
# Humidity             12804 non-null float64
# Weather              12804 non-null object
# PrecipProb           12804 non-null float64
# PrecipInten          12804 non-null float64
# Wind                 12804 non-null float64
# FireDuration         12804 non-null timedelta64[ns]
# Days                 12804 non-null int64
# dtypes: datetime64[ns](3), float64(11), int64(6), object(7), timedelta64[ns](1)
# memory usage: 3.5+ MB

# %%
dfcleaned.describe()
# Out:
#            FireYear      District          Unit    FireNumber    FiscalYear  \
# count  12804.000000  12804.000000  12804.000000  12804.000000  12804.000000
# mean    2010.885739     77.794205      1.824274    106.486489   2011.665886
# std        3.835583     14.767803      1.043033    127.973068      3.835978
# min     2005.000000     51.000000      1.000000      1.000000   2005.000000
# 25%     2007.000000     71.000000      1.000000     26.000000   2008.000000
# 50%     2011.000000     73.000000      2.000000     58.000000   2012.000000
# 75%     2014.000000     95.000000      2.000000    138.000000   2015.000000
# max     2017.000000     99.000000      5.000000    861.000000   2018.000000
#
#                 Sec       Long_DD        Lat_DD  FireTotalAcres  \
# count  12804.000000  12804.000000  12804.000000    12804.000000
# mean      18.645970   -122.227932     43.736493      172.316860
# std       10.416696      1.706404      1.236770     3263.900735
# min        1.000000   -124.536670     41.898890        0.000000
# 25%       10.000000   -123.371940     42.526040        0.010000
# 50%       19.000000   -122.810000     43.604305        0.100000
# 75%       28.000000   -121.533435     44.853678        0.500000
# max       36.000000   -116.521110     46.235000   190590.000000
#
#        ODFProtectedAcres          Temp      DewPoint      Humidity  \
# count       12804.000000  12804.000000  12804.000000  12804.000000
# mean           32.406286     69.308585     46.529243      0.489695
# std           659.342219     13.148431      8.416800      0.209875
# min             0.000000     12.480000      0.890000      0.060000
# 25%             0.010000     60.367500     41.780000      0.320000
# 50%             0.100000     69.720000     47.810000      0.450000
# 75%             0.350000     79.120000     52.640000      0.640000
# max         33788.000000    104.710000     65.970000      1.000000
#
#          PrecipProb   PrecipInten          Wind              FireDuration  \
# count  12804.000000  12804.000000  12804.000000                     12804
# mean       0.037247      0.001573      2.769237    9 days 11:52:20.257731
# std        0.133200      0.010503      2.130424  259 days 09:11:39.496089
# min        0.000000      0.000000      0.000000      -2556 days +07:30:00
# 25%        0.000000      0.000000      1.230000           0 days 01:16:00
# 50%        0.000000      0.000000      2.320000           0 days 05:30:00
# 75%        0.000000      0.000000      3.740000           1 days 09:09:15
# max        1.000000      0.397400     24.860000       24111 days 07:11:00
#
#                Days
# count  12804.000000
# mean       9.202202
# std      259.380877
# min    -2556.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max    24111.000000

# %%
#removing fires where timedelta (days) is less than zero
dfcleaned = dfcleaned[dfcleaned['Days']>=0]

# %%
#removing fires where timedelta (days) is greater than 100 days and fireacres is less than 1000
dfcleaned = dfcleaned[(dfcleaned['Days']<=100)&(dfcleaned['FireTotalAcres']<=1000)]

# %%
dfcleaned.describe()
# Out:
#            FireYear      District          Unit    FireNumber    FiscalYear  \
# count  12575.000000  12575.000000  12575.000000  12575.000000  12575.000000
# mean    2010.885249     77.690736      1.818449    106.875149   2011.663062
# std        3.836874     14.751858      1.039636    128.335022      3.837661
# min     2005.000000     51.000000      1.000000      1.000000   2005.000000
# 25%     2007.000000     71.000000      1.000000     26.000000   2008.000000
# 50%     2011.000000     73.000000      2.000000     58.000000   2012.000000
# 75%     2014.000000     95.000000      2.000000    139.000000   2015.000000
# max     2017.000000     99.000000      5.000000    861.000000   2018.000000
#
#                 Sec       Long_DD        Lat_DD  FireTotalAcres  \
# count  12575.000000  12575.000000  12575.000000    12575.000000
# mean      18.644930   -122.243341     43.732723        5.399860
# std       10.416893      1.692977      1.235887       40.353529
# min        1.000000   -124.536670     41.998890        0.000000
# 25%       10.000000   -123.372360     42.523750        0.010000
# 50%       19.000000   -122.814830     43.593890        0.100000
# 75%       28.000000   -121.544440     44.846250        0.430000
# max       36.000000   -116.783060     46.235000      966.000000
#
#        ODFProtectedAcres          Temp      DewPoint      Humidity  \
# count       12575.000000  12575.000000  12575.000000  12575.000000
# mean            4.047311     69.394596     46.615981      0.489365
# std            31.023020     13.004227      8.355507      0.208982
# min             0.000000     19.810000      0.890000      0.060000
# 25%             0.010000     60.450000     41.920000      0.320000
# 50%             0.100000     69.750000     47.890000      0.450000
# 75%             0.300000     79.110000     52.700000      0.640000
# max           840.000000    104.710000     65.970000      1.000000
#
#          PrecipProb   PrecipInten          Wind            FireDuration  \
# count  12575.000000  12575.000000  12575.000000                   12575
# mean       0.036608      0.001563      2.771551  1 days 21:27:44.927236
# std        0.132050      0.010559      2.128368  6 days 18:14:30.967904
# min        0.000000      0.000000      0.000000         0 days 00:00:00
# 25%        0.000000      0.000000      1.230000         0 days 01:15:00
# 50%        0.000000      0.000000      2.330000         0 days 05:10:00
# 75%        0.000000      0.000000      3.740000         1 days 04:39:00
# max        1.000000      0.397400     24.860000       100 days 12:32:00
#
#                Days
# count  12575.000000
# mean       1.604374
# std        6.713067
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max      100.000000

# %%
dfcleaned.drop(['ReportDateAndTime','Ign_DateTime','Control_DateTime','FireDuration'], axis=1,inplace=True)

# %%
dfcleaned.describe()
# Out:
#            FireYear      District          Unit    FireNumber    FiscalYear  \
# count  12575.000000  12575.000000  12575.000000  12575.000000  12575.000000
# mean    2010.885249     77.690736      1.818449    106.875149   2011.663062
# std        3.836874     14.751858      1.039636    128.335022      3.837661
# min     2005.000000     51.000000      1.000000      1.000000   2005.000000
# 25%     2007.000000     71.000000      1.000000     26.000000   2008.000000
# 50%     2011.000000     73.000000      2.000000     58.000000   2012.000000
# 75%     2014.000000     95.000000      2.000000    139.000000   2015.000000
# max     2017.000000     99.000000      5.000000    861.000000   2018.000000
#
#                 Sec       Long_DD        Lat_DD  FireTotalAcres  \
# count  12575.000000  12575.000000  12575.000000    12575.000000
# mean      18.644930   -122.243341     43.732723        5.399860
# std       10.416893      1.692977      1.235887       40.353529
# min        1.000000   -124.536670     41.998890        0.000000
# 25%       10.000000   -123.372360     42.523750        0.010000
# 50%       19.000000   -122.814830     43.593890        0.100000
# 75%       28.000000   -121.544440     44.846250        0.430000
# max       36.000000   -116.783060     46.235000      966.000000
#
#        ODFProtectedAcres          Temp      DewPoint      Humidity  \
# count       12575.000000  12575.000000  12575.000000  12575.000000
# mean            4.047311     69.394596     46.615981      0.489365
# std            31.023020     13.004227      8.355507      0.208982
# min             0.000000     19.810000      0.890000      0.060000
# 25%             0.010000     60.450000     41.920000      0.320000
# 50%             0.100000     69.750000     47.890000      0.450000
# 75%             0.300000     79.110000     52.700000      0.640000
# max           840.000000    104.710000     65.970000      1.000000
#
#          PrecipProb   PrecipInten          Wind          Days
# count  12575.000000  12575.000000  12575.000000  12575.000000
# mean       0.036608      0.001563      2.771551      1.604374
# std        0.132050      0.010559      2.128368      6.713067
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.230000      0.000000
# 50%        0.000000      0.000000      2.330000      0.000000
# 75%        0.000000      0.000000      3.740000      1.000000
# max        1.000000      0.397400     24.860000    100.000000

# %%
corrdf = dfcleaned[['Area','FireNumber','Long_DD','Lat_DD','FireTotalAcres','ODFProtectedAcres','Temp','DewPoint','Humidity','Weather','PrecipProb','Wind','Days']]

# %%
pplot = dfcleaned[['Area','FireTotalAcres','Temp','Humidity','PrecipProb','Wind','Days']]

# %%
pplot.describe()
# Out:
#        FireTotalAcres          Temp      Humidity    PrecipProb          Wind  \
# count    12575.000000  12575.000000  12575.000000  12575.000000  12575.000000
# mean         5.399860     69.394596      0.489365      0.036608      2.771551
# std         40.353529     13.004227      0.208982      0.132050      2.128368
# min          0.000000     19.810000      0.060000      0.000000      0.000000
# 25%          0.010000     60.450000      0.320000      0.000000      1.230000
# 50%          0.100000     69.750000      0.450000      0.000000      2.330000
# 75%          0.430000     79.110000      0.640000      0.000000      3.740000
# max        966.000000    104.710000      1.000000      1.000000     24.860000
#
#                Days
# count  12575.000000
# mean       1.604374
# std        6.713067
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max      100.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

# %%
sns.boxplot(x='FireYear',y='FireTotalAcres', data=dfcleaned)
plt.show()

# %% [markdown]
# The spread of this dataset looks to be really large.  The means and the highest fire acres is actually extremely large; this could affect the correlation and distribution of the dataset.

# %%
dfcleaned.groupby('Area')

# %%
fig, ax = plt.subplots(figsize=(15,7))
dfcleaned.groupby(['FireYear','Area']).count()['FireTotalAcres'].unstack().plot(ax=ax)
ax.set_ylabel('Total Acres Burned')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))
dfcleaned.groupby(['FireYear','HumanOrLightning']).count()['FireTotalAcres'].unstack().plot(ax=ax)
ax.set_ylabel('Total Acres Burned')
plt.show()

# %%
#count of fires per year
sns.countplot(x='FireYear',data=dfcleaned, hue='Area')
plt.show()

# %% [markdown]
# Looking at the graph above, it does not appear there are any trends with the amount of fires that has occurred. Based on the counts, it appears that there was a downward trend from 2006 to 2012.

# %%
#count of fires by area
sns.countplot(x='Area',data=dfcleaned)
plt.show()

# %%
_ = sns.pairplot(pplot,hue='Area',kind='reg', plot_kws ={'scatter_kws': {'alpha': 0.5}})

plt.show()

# %%
g = sns.pairplot(pplot, y_vars=['Humidity','Wind','Temp'], x_vars='FireTotalAcres',hue='Area',size=4, kind='reg')
plt.show()

# %% [markdown]
# Based on this pairplot, it looks like for total acres burned; the spread in NOA area is extremely large versus SOA and EOA.  Evaluating the NOA fires in depth and cleaning the dataset could show a difference.

# %%
# sns.set(style='white')
#finding a correlation matrix
corr = corrdf.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure

f, ax = plt.subplots(figsize=(18,10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# Based on this correlation plot and pairplot, it appears that the total acres burned has very little correlation with any factors except with the number of days a fire has burned and a slight correlation with temperature.  Next step is to remove the extreme values (outliers) and rerun the pairplot and correlation to see if there is a difference.

# %%
#creating a function to separate out wanted columns
def graphs(df):
    corrdf = df[['Area','FireNumber','Long_DD','Lat_DD','FireTotalAcres','ODFProtectedAcres','Temp','DewPoint','Humidity','Weather','PrecipProb','Wind','Days']]
    pplotdf = df[['Area','FireTotalAcres','Temp','Humidity','PrecipProb','Wind','Days']]
    return corrdf, pplotdf

# %%
dfcleaned['FireTotalAcres'].describe()
# Out:
# count    12575.000000
# mean         5.399860
# std         40.353529
# min          0.000000
# 25%          0.010000
# 50%          0.100000
# 75%          0.430000
# max        966.000000
# Name: FireTotalAcres, dtype: float64

# %%
df_non_neg = dfcleaned[(dfcleaned['Days']>=0)&(dfcleaned['Days']<=172)]
df_non_neg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12575 entries, 0 to 13440
# Data columns (total 24 columns):
# FireYear             12575 non-null int64
# Area                 12575 non-null object
# District             12575 non-null int64
# Unit                 12575 non-null int64
# FireNumber           12575 non-null int64
# FiscalYear           12575 non-null int64
# Twn                  12575 non-null object
# Sec                  12575 non-null float64
# Subdiv               12573 non-null object
# Long_DD              12575 non-null float64
# Lat_DD               12575 non-null float64
# HumanOrLightning     12575 non-null object
# CauseByDesc          12575 non-null object
# GeneralDesc          12574 non-null object
# FireTotalAcres       12575 non-null float64
# ODFProtectedAcres    12575 non-null float64
# Temp                 12575 non-null float64
# DewPoint             12575 non-null float64
# Humidity             12575 non-null float64
# Weather              12575 non-null object
# PrecipProb           12575 non-null float64
# PrecipInten          12575 non-null float64
# Wind                 12575 non-null float64
# Days                 12575 non-null int64
# dtypes: float64(11), int64(6), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# Removed fires that were longer than 172 days and fires that were shorter than 0 days.  172 was selected because that was the biggest fire in Oregon History that occurred in 2002.

# %%
dfunder100 = df_non_neg[df_non_neg['FireTotalAcres']<100]
dfunder100.describe()
# Out:
#            FireYear      District          Unit    FireNumber   FiscalYear  \
# count  12411.000000  12411.000000  12411.000000  12411.000000  12411.00000
# mean    2010.886472     77.562082      1.813714    107.502135   2011.66296
# std        3.836138     14.722956      1.039483    128.760423      3.83740
# min     2005.000000     51.000000      1.000000      1.000000   2005.00000
# 25%     2007.000000     71.000000      1.000000     26.000000   2008.00000
# 50%     2011.000000     73.000000      2.000000     59.000000   2012.00000
# 75%     2014.000000     95.000000      2.000000    140.000000   2015.00000
# max     2017.000000     99.000000      5.000000    861.000000   2018.00000
#
#                 Sec       Long_DD        Lat_DD  FireTotalAcres  \
# count  12411.000000  12411.000000  12411.000000    12411.000000
# mean      18.655547   -122.264743     43.724881        1.706099
# std       10.427967      1.676895      1.234648        7.452320
# min        1.000000   -124.536670     41.998890        0.000000
# 25%       10.000000   -123.374165     42.521670        0.010000
# 50%       19.000000   -122.818670     43.578060        0.100000
# 75%       28.000000   -121.566500     44.829445        0.340000
# max       36.000000   -116.783060     46.235000       99.350000
#
#        ODFProtectedAcres          Temp      DewPoint      Humidity  \
# count       12411.000000  12411.000000  12411.000000  12411.000000
# mean            1.483098     69.332893     46.674510      0.490994
# std             6.651744     12.975599      8.327616      0.208584
# min             0.000000     19.810000      0.890000      0.060000
# 25%             0.010000     60.405000     41.965000      0.320000
# 50%             0.100000     69.670000     47.950000      0.460000
# 75%             0.250000     79.020000     52.730000      0.640000
# max            99.350000    104.710000     65.970000      1.000000
#
#          PrecipProb   PrecipInten          Wind          Days
# count  12411.000000  12411.000000  12411.000000  12411.000000
# mean       0.036532      0.001566      2.765854      1.518895
# std        0.131815      0.010603      2.124507      6.541865
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.230000      0.000000
# 50%        0.000000      0.000000      2.320000      0.000000
# 75%        0.000000      0.000000      3.730000      1.000000
# max        1.000000      0.397400     24.860000    100.000000

# %%
corr100, pplot100 = graphs(dfunder100)

# %%
_ = sns.pairplot(pplot100,hue='Area',kind='reg', plot_kws ={'scatter_kws': {'alpha': 0.5}})

plt.show()

# %% [markdown]
# Based on these plots, it appears that there is a little more spread in the behavior of wind and temp.  Most of the data is sitting at the bottom.

# %%
g = sns.pairplot(pplot100, y_vars=['Humidity','Wind','Temp'], x_vars='FireTotalAcres',hue='Area',size=4, kind='reg')
plt.show()

# %%
# sns.set(style='white')
#finding a correlation matrix
corr = corr100.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure

f, ax = plt.subplots(figsize=(18,10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# It appears by isolating some of the smaller fires (less than 100 acres) which accounts for over 99% of the data points, there is a stronger correlation with wind and less of a correlation with temperature.  It appears that dewpoint has a better correlation than temperature for fires that are smaller than 100 acres.

# %%
import pickle
pickle_out=open('under100.pickle','wb')
pickle.dump(dfunder100, pickle_out)
