# %%
import time
from selenium import webdriver

# %%
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-776375a4decd> in <module>()
#       1 driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
# ----> 2 driver.get('junglescout.com')
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     262         Loads a web page in the current browser session.
#     263         """
# --> 264         self.execute(Command.GET, {'url': url})
#     265
#     266     @property
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     250         response = self.command_executor.execute(driver_command, params)
#     251         if response:
# --> 252             self.error_handler.check_response(response)
#     253             response['value'] = self._unwrap_value(
#     254                 response.get('value', None))
#
# /usr/local/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: unhandled inspector error: {"code":-32000,"message":"Cannot navigate to invalid URL"}
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.36.540469 (1881fd7f8641508feb5166b7cae561d87723cfa8),platform=Mac OS X 10.13.4 x86_64)

# %%
driver.get('https://members.junglescout.com/#/login')

# %%
driver.page_source
# Out:
# '<!DOCTYPE html><!--[if IE 9]><html class="no-js ie9" lang="en-US" prefix="og: http://ogp.me/ns#"><![endif]--><!--[if gt IE 9]><!--><html xmlns="http://www.w3.org/1999/xhtml" class="js no-touchevents cssanimations csspointerevents csstransforms supports csstransforms3d preserve3d csstransitions" lang="en-US" prefix="og: http://ogp.me/ns#"><!--<![endif]--><head><meta charset="UTF-8" /><meta name="viewport" content="width=device-width, initial-scale=1.0" /><link type="text/css" media="all" href="https://yj4dfcucm3mswcd2nbkkg14m-wpengine.netdna-ssl.com/wp-content/cache/autoptimize/css/autoptimize_8c1ae9b9cda7ee89323a2f492cff1ae3.css" rel="stylesheet" /><title>Amazon Product Finder &amp; Market Research Tool - Find Sales Data Fast! | Jungle Scout: Amazon Product Research Made Easy</title><link rel="pingback" href="https://www.junglescout.com/xmlrpc.php" /><link rel="canonical" href="https://www.junglescout.com/" /><meta property="og:locale" content="en_US" /><meta property="og:type" content="website" /><meta property="og:title" content="Amazon Product Finder &amp; Market Research Tool - Find Sales Data Fast! | Jungle Scout: Amazon Product Research Made Easy" /><meta property="og:url" content="https://www.junglescout.com/" /><meta property="og:site_name" content="Jungle Scout: Amazon Product Research Made Easy" /><meta name="twitter:card" content="summary" /><meta name="twitter:title" content="Amazon Product Finder &amp; Market Research Tool - Find Sales Data Fast! | Jungle Scout: Amazon Product Research Made Easy" /> <script async="" src="https://s.pinimg.com/ct/core.js"></script><script async="" src="https://a.quora.com/qevents.js"></script><script src="//bat.bing.com/bat.js" async=""></script><script src="https://connect.facebook.net/signals/config/327254374150717?v=2.8.24&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://cdn.pushcrew.com/js/887fc4c9b6c18de8e57b97727469f4a6.js"></script><script type="text/javascript" async="" src="//static.ads-twitter.com/uwt.js"></script><script type="text/javascript" async="" src="//static.hotjar.com/c/hotjar-286568.js?sv=5"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-TJXJ6N"></script><script type="text/javascript" async="" src="//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js"></script><script type="application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"WebSite","@id":"#website","url":"https:\\/\\/www.junglescout.com\\/","name":"Jungle Scout: Amazon Product Research Made Easy","potentialAction":{"@type":"SearchAction","target":"https:\\/\\/www.junglescout.com\\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script> <script type="application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"Organization","url":"https:\\/\\/www.junglescout.com\\/","sameAs":[],"@id":"https:\\/\\/www.junglescout.com\\/#organization","name":"Jungle Scout","logo":""}</script> <link rel="dns-prefetch" href="//a.optmnstr.com" /><link rel="alternate" type="application/rss+xml" title="Jungle Scout: Amazon Product Research Made Easy » Feed" href="https://www.junglescout.com/feed/" /><link rel="alternate" type="application/rss+xml" title="Jungle Scout: Amazon Product Research Made Easy » Comments Feed" href="https://www.junglescout.com/comments/feed/" /> <script type="text/javascript">var slide_in = {"demo_dir":"https:\\/\\/www.junglescout.com\\/wp-content\\/plugins\\/convertplug\\/modules\\/slide_in\\/assets\\/demos"};</script> <script type="text/javascript" src="https://yj4dfcucm3mswcd2nbkkg14m-wpengine.netdna-ssl.com/wp-includes/js/jquery/jquery.js"></script> <script type="text/javascript" data-cfasync="false" id="omapi-script" async="async" src="https://a.opt ...

# %%
user_element, password_element = driver.find_elements_by_class_name("sc-dxgOiQ")

# %%
user_element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8563349899d97dbc418dfc4257b05394", element="0.6228760776817759-1")>

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
ActionChains(driver) \
    .send_keys("rudimentalrx@gmail.com") \
    .send_keys(Keys.TAB) \
    .send_keys("Yujun123") \
    .send_keys(Keys.ENTER) \
    .perform()

# %%
driver.get('https://members.junglescout.com/#/database')

# %%
word_search = driver.find_elements_by_class_name("word-search__input")

# %%
word_search[0].click()

# %%
ActionChains(driver) \
    .send_keys("container")  \
    .perform()

# %%
search_boxes = driver.find_elements_by_tag_name("button")

# %%
len(search_boxes)
# Out:
# 18

# %%
search_boxes[4].click()

# %%
#button for csv 5

# %%
table_rows = driver.find_elements_by_class_name("table__row")

# %%
len(table_rows)
# Out:
# 26

# %%
row = table_rows[1]

# %%
def row_cleaner(row):
    return [element.text for element in row.find_elements_by_class_name("table__cell__section--full")]

# %%
row_cleaner(table_rows[1])
# Out:
# ['" Chocolate Bite" LIP GLOSS INTENSE - 0.27 Fluid Oz. (Container w/ Applicator) by \'RED NEW YORK\' || Made in USA.|| Ultra Smooth, rich colored | Protection, Long lasting, Soft - NIB',
#  'ASIN:\nB077CJDM3J ',
#  'Category:\nHealth & Household',
#  'Brand:\nRED New York',
#  'Seller:\nSelect Bargains',
#  'Price:\n$8.95',
#  'Fees:\n$4.33',
#  'Net:\n$4.62',
#  '0.06 lbs',
#  '',
#  '(0)',
#  '1,246,399',
#  '1',
#  '65',
#  '< 5',
#  '< $44.75']
